# %% [markdown]
# This is an example of a simple CNN developed, trained and utilized
#
# AI was used to help generate the codebase
#
# Note: Make sure that the tensorflow package is installed in your device.

# %%
# Lib imports
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications import ResNet50
import numpy as np
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Axel John Nuqui\AppData\Local\Temp\ipykernel_16832\3185145416.py", line 3, in <module>
#     import tensorflow as tf
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\tensorflow\__init__.py", line 468, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\__init__.py", line 7, in <module>
#     from keras import _tf_keras as _tf_keras
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\_tf_keras\__init__.py", line 1, in <module>
#     from keras._tf_keras import keras
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\_tf_keras\keras\__init__.py", line 7, in <module>
#     from keras import activations as activations
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize as deserialize
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\src\__init__.py", line 13, in <module>
#     from keras.src import visualization
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\src\visualization\__init__.py", line 1, in <module>
#     from keras.src.visualization import draw_bounding_boxes
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\src\visualization\draw_bounding_boxes.py", line 11, in <module>
#     import cv2
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\cv2\__init__.py", line 181, in <module>
#     bootstrap()
#   File "c:\PROJECTS\ai_ml\venv\lib\site-packages\cv2\__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "C:\Users\Axel John Nuqui\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# DATASET DIRECTORY CONFIGURATION
# Download and unzip the dataset from Kaggle, set the directory paths accordingly.
train_dir = muffin-vs-chihuahua\train"
test_dir  = muffin-vs-chihuahua\test"

# %%
# IMAGE PARAMETERS
# Used to resize the input images, also will determine the input size of your input layer.
IMG_SIZE = (128, 128)
BATCH_SIZE = 32

# %%
# DATA PREPROCESSING & AUGMENTATION
# Optional but recommended for image processing tasks, especially with limited data.
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training'
)
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation'
)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 6400 images belonging to 2 classes.
# Found 1600 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
initial_learning_rate = 0.001

# We are combining ExponentialDecay with Adam optimizer
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# Load pretrained ResNet50 (no top layers)
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(128, 128, 3)
)

# Freeze pretrained weights
base_model.trainable = False

# Build new model on top
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# c:\PROJECTS\ai_ml\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Configure the model optimizers, loss function, and metrics
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # old
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# TRAINING THE CNN
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 142s 699ms/step - accuracy: 0.6100 - loss: 0.8577 - val_accuracy: 0.5175 - val_loss: 0.7971
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.7328 - loss: 0.6412 - val_accuracy: 0.8087 - val_loss: 0.5262
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 62s 308ms/step - accuracy: 0.7738 - loss: 0.5684 - val_accuracy: 0.8225 - val_loss: 0.5263
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 61s 306ms/step - accuracy: 0.7995 - loss: 0.5232 - val_accuracy: 0.8556 - val_loss: 0.4583
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 62s 311ms/step - accuracy: 0.8220 - loss: 0.4902 - val_accuracy: 0.8363 - val_loss: 0.4720
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 60s 302ms/step - accuracy: 0.8239 - loss: 0.4841 - val_accuracy: 0.8675 - val_loss: 0.4199
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 318ms/step - accuracy: 0.8363 - loss: 0.4770 - val_accuracy: 0.8631 - val_loss: 0.4065
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 321ms/step - accuracy: 0.8477 - loss: 0.4484 - val_accuracy: 0.8869 - val_loss: 0.3599
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 321ms/step - accuracy: 0.8550 - loss: 0.4309 - val_accuracy: 0.8838 - val_loss: 0.3762
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 319ms/step - accuracy: 0.8539 - loss: 0.4307 - val_accuracy: 0.8725 - val_loss: 0.4313

# %%
# EVALUATE THE MODEL
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 331ms/step - accuracy: 0.9070 - loss: 0.3658
# Test Accuracy: 0.9070000052452087

# %%
# SAVE THE MODEL
model.save('muffin_vs_chihuahua_cnn_resnet.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.preprocessing import image

def predict_image(img_path, model_path='muffin_vs_chihuahua_cnn_resnet.h5'):
    model = tf.keras.models.load_model(model_path)
    img = image.load_img(img_path, target_size=IMG_SIZE)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    pred = model.predict(img_array)[0,0]
    label = "Muffin" if pred >= 0.5 else "Chihuahua"
    print(f"Prediction: {label} (confidence: {pred:.2f})")

# %%
# Example usage:
predict_image("run_1/run_1.jpg")
predict_image("run_1/run_2.jpg")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\PROJECTS\ai_ml\venv\lib\site-packages\PIL\Image.py:1039: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Prediction: Shoe (confidence: 0.99)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Prediction: Sandal (confidence: 0.36)
